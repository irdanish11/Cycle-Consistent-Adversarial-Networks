# %%
# %cd ..
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# /
# Mounted at /content/gdrive

# %%
# this creates a symbolic link so that now the path /content/gdrive/My\ Drive/ is equal to /mydrive
# !ln -s /content/gdrive/MyDrive/Classroom/'Deep Learning Spring 21'/Project/code/Cycle-Consistent-Adversarial-Networks/dataset/data /mydrive
# !ls /mydrive
# Out:
# horse2zebra  horse2zebra.npz  horse2zebra.zip  summer2winter_yosemite.zip

# %%
# !mkdir project

# %%
import os
os.chdir('project')
# !ls

# %%
# !git clone https://github.com/irdanish11/Cycle-Consistent-Adversarial-Networks.git
# Out:
# Cloning into 'Cycle-Consistent-Adversarial-Networks'...
# remote: Enumerating objects: 125, done.
# remote: Counting objects: 100% (125/125), done.
# remote: Compressing objects: 100% (97/97), done.
# remote: Total 125 (delta 45), reused 79 (delta 17), pack-reused 0
# Receiving objects: 100% (125/125), 100.60 MiB | 38.71 MiB/s, done.
# Resolving deltas: 100% (45/45), done.

# %%
# !mkdir Cycle-Consistent-Adversarial-Networks/dataset/data/

# %%
# !cp -v /mydrive/horse2zebra.npz Cycle-Consistent-Adversarial-Networks/dataset/data/
# !ls Cycle-Consistent-Adversarial-Networks/dataset/data
# Out:
# '/mydrive/horse2zebra.npz' -> 'Cycle-Consistent-Adversarial-Networks/dataset/data/horse2zebra.npz'
# horse2zebra.npz

# %%
os.chdir('Cycle-Consistent-Adversarial-Networks/src')
# !ls
# Out:
# datagen.py  nn.py  train.ipynb	train.py  utils.py

# %%
# !ln -s /content/gdrive/MyDrive/Classroom/'Deep Learning Spring 21'/Project/code/Cycle-Consistent-Adversarial-Networks/src/dump /dump
# !ls /dump
# Out:
# horse2zebra

# %% [markdown]
# # Training

# %%
#training
# !python train.py --dumppath /dump
# Out:
# Dump Path:  /dump
#
# Loading data from path: ../dataset/data/horse2zebra.npz
# PyTorch version: 1.8.1+cu101
# CUDA version: 10.1
#
# Random Seed:  4040
# Device:  cuda:0
#
# Checkpoints found at epoch: 7, Paths:
# ['/dump/horse2zebra/ckpt/7/generator_A2B.pth', '/dump/horse2zebra/ckpt/7/generator_B2A.pth', '/dump/horse2zebra/ckpt/7/discriminator_A.pth', '/dump/horse2zebra/ckpt/7/discriminator_B.pth']
#
# Checkpoints found at epoch 7, do you want to resume training (Y/n): y
# y
# Training will resume from epoch: 7
#
# 			________________________________________________________
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/loss.py:528: UserWarning: Using a target size (torch.Size([1, 1])) that is different to the input size (torch.Size([1, 1, 29, 29])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# Epoch: 8/100 | Batch: 1472/1472 | Generator Loss: 5.1140 | Discriminator Loss: 0.1042 | Identity Loss: 1.4095 | Adversarial Loss: 0.7497 | Cycle Loss: 2.9548 | Discriminator Loss A: 0.0233 | Discriminator Loss B: 0.0808 | Traceback (most recent call last):
#   File "train.py", line 275, in <module>
#     DUMP_PATH)
#   File "train.py", line 239, in train_cycle_gan
#     update_epoch_stats(epoch, epoch_history, history, time_taken)
#   File "/project/Cycle-Consistent-Adversarial-Networks/src/utils.py", line 85, in update_epoch_stats
#     info = get_info_string(idx, history)
#   File "/project/Cycle-Consistent-Adversarial-Networks/src/utils.py", line 67, in get_info_string
#     + 'Discriminator Loss B: {0:.4f} | '.format(
# IndexError: list index out of range
