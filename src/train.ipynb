# %%
# %cd ..
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# /
# Mounted at /content/gdrive

# %%
# this creates a symbolic link so that now the path /content/gdrive/My\ Drive/ is equal to /mydrive
# !ln -s /content/gdrive/MyDrive/Classroom/'Deep Learning Spring 21'/Project/code/Cycle-Consistent-Adversarial-Networks/dataset/data /mydrive
# !ls /mydrive
# Out:
# horse2zebra  horse2zebra.npz  horse2zebra.zip  summer2winter_yosemite.zip

# %%
# !mkdir project
# Out:
# 'mydrive/horse2zebra.npz' -> '/project/horse2zebra.npz'

# %%
import os
os.chdir('project')
# !ls
# Out:
# horse2zebra.npz

# %%
# !git clone https://github.com/irdanish11/Cycle-Consistent-Adversarial-Networks.git
# Out:
# Cloning into 'Cycle-Consistent-Adversarial-Networks'...
# remote: Enumerating objects: 105, done.
# remote: Counting objects: 100% (105/105), done.
# remote: Compressing objects: 100% (82/82), done.
# remote: Total 105 (delta 33), reused 68 (delta 12), pack-reused 0
# Receiving objects: 100% (105/105), 100.59 MiB | 39.09 MiB/s, done.
# Resolving deltas: 100% (33/33), done.

# %%
# !mkdir Cycle-Consistent-Adversarial-Networks/dataset/data/

# %%
# !cp -v /mydrive/horse2zebra.npz Cycle-Consistent-Adversarial-Networks/dataset/data/
# !ls Cycle-Consistent-Adversarial-Networks/dataset/data
# Out:
# '/mydrive/horse2zebra.npz' -> 'Cycle-Consistent-Adversarial-Networks/dataset/data/horse2zebra.npz'
# horse2zebra.npz

# %%
os.chdir('Cycle-Consistent-Adversarial-Networks/src')
# !ls
# Out:
# datagen.py  nn.py  train.py  utils.py

# %% [markdown]
# # Training

# %%
#training
# !python train.py
# Out:
# Loading data from path: ../dataset/data/horse2zebra.npz
# PyTorch version: 1.8.1+cu101
# CUDA version: 10.1
#
# Random Seed:  8050
# Device:  cuda:0
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/loss.py:528: UserWarning: Using a target size (torch.Size([1, 1])) that is different to the input size (torch.Size([1, 1, 29, 29])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# Epoch: 1/1 | Batch: 1472/1472 | Generator Loss: 8.8313 | Discriminator Loss: 0.1193 | Identity Loss: 2.2498 | Adversarial Loss: 1.9351 | Cycle Loss: 4.6463 |Discriminator Loss A: 0.0755 | Discriminator Loss B: 0.0437 | Epoch Completed. - Time Taken by epoch: 0:11:50.
# Generator Loss: 9.2340 | Discriminator Loss: 0.3434 | Identity Loss: 2.6160 | Adversarial Loss: 0.9884 | Cycle Loss: 5.6296 |Discriminator Loss A: 0.1779 | Discriminator Loss B: 0.1655 |
#
# Saving Models
#
# 100% 4/4 [00:00<00:00, 19.61it/s]
# Images Saved at path: dump/horse2zebra/images/1

# %% [markdown]
# # Plotting & Saving Model

# %%
#testing images
test_encoder_decoder(test_images='test', dump_path='dump')

# %%
#copying back to drive
# !cp -r -v dump /mydrive
